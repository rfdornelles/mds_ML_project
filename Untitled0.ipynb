# %% [markdown]
# <a href="https://colab.research.google.com/github/rfdornelles/mds_ML_project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Absolute deaths from ambient PM2.5 air pollution- State of Global Air.csv

# %%
pd.read_csv("/content/Absolute deaths from ambient PM2.5 air pollution- State of Global Air.csv")

# %% [markdown]
# Berlin Brandenburg Energy Usage - Option C.xlsx

# %%
pd.read_excel("/content/Berlin Brandenburg Energy Usage - Option C.xlsx")
# Out:
#   Energieverwendung des\nVerarbeitenden Gewerbes 2020 Einheit Berlin  \
# 0                                                NaN      NaN    NaN
# 1                                   Energieverbrauch       TJ  10934
# 2                                              Kohle       TJ      •
# 3                                             Heizöl       TJ      •
# 4                                             Erdgas       TJ   4190
# 5                               Erneuerbare Energien       TJ      •
# 6                                              Strom       TJ   5136
# 7                                              Wärme       TJ    960
# 8                             Sonstige Energieträger       TJ     22
#
#    Brandenburg Berlin und\nBrandenburg
# 0          NaN                     NaN
# 1     185304.0                  196238
# 2      32570.0                       •
# 3       1149.0                       •
# 4      32419.0                   36609
# ...

# %% [markdown]
# Data_hub_Global Temperature Time Series_monthly.csv

# %%
pd.read_csv("/content/Data_hub_Global Temperature Time Series_monthly.csv")
# Out:
#        Source        Date    Mean
# 0        GCAG  2016-12-06  0.7895
# 1     GISTEMP  2016-12-06  0.8100
# 2        GCAG  2016-11-06  0.7504
# 3     GISTEMP  2016-11-06  0.9300
# 4        GCAG  2016-10-06  0.7292
# ...       ...         ...     ...
# 3283  GISTEMP  1880-03-06 -0.1800
# 3284     GCAG  1880-02-06 -0.1229
# 3285  GISTEMP  1880-02-06 -0.2100
# 3286     GCAG  1880-01-06  0.0009
# 3287  GISTEMP  1880-01-06 -0.3000
#
# [3288 rows x 3 columns]

# %% [markdown]
# Deaths_Germany, years, nationality, sex, age years.csv

# %%
pd.read_csv("/content/Deaths_Germany, years, nationality, sex, age years.csv")

# %% [markdown]
# Excess Mortality Data – OWID (2022).csv

# %% [markdown]
# German Mortality Data.xlsx

# %% [markdown]
# Weekly Death Rates in Berlin 2021 - 2022.csv

# %%
pd.read_csv("/content/Weekly Death Rates in Berlin 2021 - 2022.csv", delimiter = ";")
# Out:
#     Kategorie  2018-2021 (Median) (x)  2018-2021 (Median) (y)  \
# 0           1                       1                     695
# 1           2                       2                     709
# 2           3                       3                     750
# 3           4                       4                     720
# 4           5                       5                     744
# 5           6                       6                     758
# 6           7                       7                     767
# 7           8                       8                     745
# 8           9                       9                     781
# 9          10                      10                     721
# 10         11                      11                     722
# 11         12                      12                     685
# 12         13                      13                     712
# 13         14                      14                     722
# ...
